# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
headers = ["p_id", "p_title", "vendor_id", "cluster_id", "cluster_title", "cat_id", "cat_title"]
df = pd.read_csv('datasets/pricerunner_aggregate.csv', header=0, names = headers)
df.head()
# Out:
#    p_id                                            p_title  vendor_id  \
# 0     2                apple iphone 8 plus 64 gb spacegrau          2
# 1     3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...          3
# 2     4                apple iphone 8 plus 64gb space grey          4
# 3     5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...          5
# 4     6  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...          6
#
#    cluster_id             cluster_title  cat_id      cat_title
# 0           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 1           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 2           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 3           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 4           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones

# %%
df[df.cluster_id == 1]
# Out:
#     p_id                                            p_title  vendor_id  \
# 0      2                apple iphone 8 plus 64 gb spacegrau          2
# 1      3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...          3
# 2      4                apple iphone 8 plus 64gb space grey          4
# 3      5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...          5
# 4      6  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...          6
# 5      7               apple iphone 8 plus 64 gb space grey          7
# 6      8                apple iphone 8 plus 64gb space grey          8
# 7      9                apple iphone 8 plus 64gb space grey          9
# 8     10                apple iphone 8 plus 64gb space grey         10
# 9     11  apple iphone 8 plus 5.5 single sim 4g 64gb silver         11
# 10    12    sim free iphone 8 plus 64gb by apple space grey         12
# 11    13           apple iphone 8 plus 64gb gold smartphone         13
# 12    14    apple iphone 8 plus 5.5 single sim 4g 64gb grey         14
# 13    15  apple iphone 8 plus silver 5.5 64gb 4g unlocke...         15
# 14    16                   apple iphone 8 plus 64 gb silver         16
# 15    17           apple iphone 8 plus 64gb silver unlocked         17
# 16    18  apple iphone 8 plus 14 cm 5.5 64 gb 12 mp ios ...         18
# 17    19  iphone 8 plus sim free water dust resistant 64...         19
# 18    20                      iphone 8 plus 64gb space grey         20
# 19    21                                apple iphone 8 plus         21
# 20    22  sim free iphone 8 plus 64gb mobile phone space...         22
# 21    23  apple mq8m2b/a 5.5 iphone 8 plus 64gb silver i...         23
#
#     cluster_id             cluster_title  cat_id      cat_title
# 0            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 1            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 2            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 3            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 4            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 5            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 6            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 7            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 8            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 9            1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 10           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 11           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 12           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 13           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 14           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 15           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 16           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 17           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 18           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 19           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 20           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones
# 21           1  Apple iPhone 8 Plus 64GB    2612  Mobile Phones

# %%
# Número de clusters.
print("Number of clusters: ", len(set(df.cluster_id)))
# Número de categorias.
print("Number of categs: ", len(set(df.cat_id)))
# Quantidade de nomes únicos.
print("Number of uniq names: ", len(set(df.cluster_title)))
# Out:
# Number of clusters:  13233
# Number of categs:  10
# Number of uniq names:  12849

# %% [markdown]
# ## Número de produtos por categoria.

# %%
print(df.cat_title.value_counts())
# Out:
# Fridge Freezers     5501
# Mobile Phones       4080
# Washing Machines    4044
# CPUs                3862
# Fridges             3584
# TVs                 3564
# Dishwashers         3424
# Digital Cameras     2697
# Microwaves          2342
# Freezers            2212
# Name: cat_title, dtype: int64

# %%
df.cat_title.value_counts().plot(kind="bar", xlabel="Categs.", ylabel="Qtde", grid=True)
# Out:
# <AxesSubplot:xlabel='Categs.', ylabel='Qtde'>

# %% [markdown]
# ## Tipos de protudos e categorias existentes na base de dados.

# %%
df.drop_duplicates(subset=["cat_id","cat_title"])
# Out:
#         p_id                                            p_title  vendor_id  \
# 0          2                apple iphone 8 plus 64 gb spacegrau          2
# 4080   10035  samsung ue49nu7100 49 ultra hd certified hdr s...         32
# 7644   13771  amd ryzen 7 eight core 1700x 3.80ghz socket am...          5
# 11506  21063                             canon ixus 185 schwarz        247
# 14203  23766  bosch hmt72m450b silver freestanding microwave...        132
# 16545  26300  bosch sms25aw00g 60cm serie 2 freestanding dis...        301
# 19969  30131  bosch wiw28300gb serie 6 8kg 1400rpm integrate...          6
# 24013  34726                 bosch gud15a50gb/02 freezer drawer          3
# 26225  37216                    bosch kgn34nw3ag fridge freezer        129
# 31726  43392  bosch kur15a50gb built in under larder fridge ...        125
#
#        cluster_id                     cluster_title  cat_id         cat_title
# 0               1          Apple iPhone 8 Plus 64GB    2612     Mobile Phones
# 4080         4419                Samsung UE49NU7100    2614               TVs
# 7644         5851      AMD Ryzen 7 1700X 3.4GHz Box    2615              CPUs
# 11506       38848                    Canon IXUS 185    2617   Digital Cameras
# 14203       39647  Bosch HMT72M450B Stainless Steel    2618        Microwaves
# 16545       40464            Bosch SMS25AW00G White    2619       Dishwashers
# 19969       41862                  Bosch WIW28300GB    2620  Washing Machines
# 24013       43262       Bosch GUD15A50GB Integrated    2621          Freezers
# 26225       44038            Bosch KGN34NW3AG White    2622   Fridge Freezers
# 31726       46113       Bosch KUR15A50GB Integrated    2623           Fridges

# %% [markdown]
# ## Média e desvio padrão da variação de produtos associados a um único ID_CLSUTER.

# %%
cats = list(set(df.cat_title))
cats.sort()
values = []
for cat in cats:
    cat_df = df[df.cat_title == cat]
    pus_by_cat = cat_df.cluster_id.value_counts()
    m = np.mean(pus_by_cat.values)
    s = np.std(pus_by_cat.values)
    values.append([cat, m, s])

info = pd.DataFrame(values, columns=["Cat", "Mean", "Std"])
info.head(20)
# Out:
#                 Cat      Mean       Std
# 0              CPUs  1.955443  1.473492
# 1   Digital Cameras  3.782609  3.546388
# 2       Dishwashers  2.502924  2.157536
# 3          Freezers  2.910526  2.217726
# 4   Fridge Freezers  2.753253  2.280543
# 5           Fridges  2.610342  1.923242
# 6        Microwaves  2.983439  2.280570
# 7     Mobile Phones  2.394366  2.678924
# 8               TVs  2.784375  3.164067
# 9  Washing Machines  3.166797  2.855358

# %% [markdown]
# ## Plot da quantidade de produtos associados a um CLUSTER_ID

# %%
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel(xlabel="Frequence", fontsize=16)
plt.ylabel(ylabel='Number of Products', fontsize=16)
df.cluster_id.value_counts().value_counts().plot(kind='barh', grid=True, figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Frequence', ylabel='Number of Products'>

# %% [markdown]
# ## Plot da quantidade de nomes únicos associados por CLUSTE_ID.

# %%
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel(xlabel="Frequence", fontsize=16)
plt.ylabel(ylabel='Number of Products', fontsize=16)
df.drop_duplicates(subset=['p_title']).cluster_id.value_counts().value_counts().plot(kind='barh', grid=True, figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Frequence', ylabel='Number of Products'>

# %% [markdown]
# # Analisando a base SKROUTZ

# %%
headers = ["p_id", "p_title", "vendor_id", "cluster_id", "cluster_title", "cat_id", "cat_title"]
df = pd.read_csv('datasets/skroutz_aggregate.csv', header=0, names = headers)
df.head()
# Out:
#    p_id                                          p_title  vendor_id  \
# 0     2                                 amd ryzen 5 1600       3964
# 1     3  amd ryzen 5 1600 box pliromi ke se eos 36 dosis       4814
# 2     4                   amd ryzen 5 1600 yd1600bbaebox       4835
# 3     5               amd ryzen 5 1600 box yd1600bbaebox       2976
# 4     6                   amd ryzen 5 1600 yd1600bbaebox       3427
#
#    cluster_id         cluster_title  cat_id cat_title
# 0           1  AMD Ryzen 5 1600 Box     696      CPUs
# 1           1  AMD Ryzen 5 1600 Box     696      CPUs
# 2           1  AMD Ryzen 5 1600 Box     696      CPUs
# 3           1  AMD Ryzen 5 1600 Box     696      CPUs
# 4           1  AMD Ryzen 5 1600 Box     696      CPUs

# %%
df[df.cluster_id == 1]
# Out:
#     p_id                                            p_title  vendor_id  \
# 0      2                                   amd ryzen 5 1600       3964
# 1      3    amd ryzen 5 1600 box pliromi ke se eos 36 dosis       4814
# 2      4                     amd ryzen 5 1600 yd1600bbaebox       4835
# 3      5                 amd ryzen 5 1600 box yd1600bbaebox       2976
# 4      6                     amd ryzen 5 1600 yd1600bbaebox       3427
# 5      7                                   amd ryzen 5 1600       1996
# 6      8                                   amd ryzen 5 1600       1712
# 7      9                      amd ryzen 5 1600 eos 24 dosis       3054
# 8     10                   amd ryzen 5 1600 box am4 3 4 ghz        282
# 9     11  amd ryzen 5 1600 box yd1600bbaebox pliromi eos...       4691
# 10    12  amd cpu ryzen 5 1600 6c/12t 3.2 3.6ghz yd1600b...       1840
# 11    13        amd ryzen 5 1600 3.20ghz 19mb yd1600bbaebox        251
# 12    14     epexergastis cpu ryzen 5 1600 am4 3.60ghz 19mb        336
# 13    15  amd ryzen 5 1600 3.2 ghz six core socket am4 6...         54
# 14    16  epexergastis amd ryzen 5 1600 6 core processor...       4455
# 15    17  amd ryzen 5 1600 6 core processor 3.2ghz yd160...       3032
# 16    18  amd cpu ryzen 5 1600 up to 3.7ghz/19mb sam4 6 ...          7
# 17    19  amd ryzen 5 1600 with wraith spire cooling yd1...       4223
# 18    20                               amd ryzen 5 1600 box       4951
# 19    21        amd epexergastis ryzen 5 1600 yd1600bbaebox       2946
# 20    22  amd ryzen 5 1600 3.4 ghz 6 core 12 threads yd1...        101
# 21    23  amd ryzen 5 1600 box epexergastis cpu am4 3.20...       1509
# 22    24  amd ryzen 5 1600 6 core processor 3.2ghz yd160...       4657
# 23    25  amd ryzen 5 1600 am4 6 core 3.2 3.6ghz yd1600b...        299
# 24    26  amd cpu ryzen 5 1600 6c/12t 3.2 3.6ghz cache 3...       3331
# 25    27                     amd ryzen 5 1600 yd1600bbaebox        891
# 26    28  amd ryzen 5 1600 3.2ghz 16mb l3 box processor ...       3021
# 27    29  amd ryzen 5 1600 3.60ghz 6 core with wraith sp...        670
# 28    30  epexergastis amd am4 ryzen 5 1600 3.2 ghz yd16...       4412
# 29    31                 amd cpu ryzen 5 1600 yd1600bbaebox          9
# 30    32                                   amd ryzen 5 1600        966
# 31    33                           cpu amd am4 ryzen 5 1600       2164
# 32    34  amd ryzen 5 1600 wraith 3200 am4 box wraith sp...       2723
# 33    35     amd ryzen 5 1600 wraith processor eos 36 dosis        246
# 34    36  epexergastis cpu ryzen 5 1600 am4 3.60ghz 19mb...        956
# 35    37  amd ryzen 5 1600 with wraith spire 65w cooler ...         18
# 36    38                            amd ryzen 5 1600 wraith       4769
# 37    39                       cpu amd ryzen 5 1600 am4 box       2863
# 38    40  epexergastis amd ryzen 5 1600 3.2ghz box yd160...       2105
# 39    41  amd cpu ryzen 5 1600 6c/12t 3.2 3.6ghz cache 3...       2660
# 40    42  amd cpu 6core ryzen 5 1600 3.2ghz am4 epexerga...       1761
#
#     cluster_id         cluster_title  cat_id cat_title
# 0            1  AMD Ryzen 5 1600 Box     696      CPUs
# 1            1  AMD Ryzen 5 1600 Box     696      CPUs
# 2            1  AMD Ryzen 5 1600 Box     696      CPUs
# 3            1  AMD Ryzen 5 1600 Box     696      CPUs
# 4            1  AMD Ryzen 5 1600 Box     696      CPUs
# 5            1  AMD Ryzen 5 1600 Box     696      CPUs
# 6            1  AMD Ryzen 5 1600 Box     696      CPUs
# 7            1  AMD Ryzen 5 1600 Box     696      CPUs
# 8            1  AMD Ryzen 5 1600 Box     696      CPUs
# 9            1  AMD Ryzen 5 1600 Box     696      CPUs
# 10           1  AMD Ryzen 5 1600 Box     696      CPUs
# 11           1  AMD Ryzen 5 1600 Box     696      CPUs
# 12           1  AMD Ryzen 5 1600 Box     696      CPUs
# 13           1  AMD Ryzen 5 1600 Box     696      CPUs
# 14           1  AMD Ryzen 5 1600 Box     696      CPUs
# 15           1  AMD Ryzen 5 1600 Box     696      CPUs
# 16           1  AMD Ryzen 5 1600 Box     696      CPUs
# 17           1  AMD Ryzen 5 1600 Box     696      CPUs
# 18           1  AMD Ryzen 5 1600 Box     696      CPUs
# 19           1  AMD Ryzen 5 1600 Box     696      CPUs
# 20           1  AMD Ryzen 5 1600 Box     696      CPUs
# 21           1  AMD Ryzen 5 1600 Box     696      CPUs
# 22           1  AMD Ryzen 5 1600 Box     696      CPUs
# 23           1  AMD Ryzen 5 1600 Box     696      CPUs
# 24           1  AMD Ryzen 5 1600 Box     696      CPUs
# 25           1  AMD Ryzen 5 1600 Box     696      CPUs
# 26           1  AMD Ryzen 5 1600 Box     696      CPUs
# 27           1  AMD Ryzen 5 1600 Box     696      CPUs
# 28           1  AMD Ryzen 5 1600 Box     696      CPUs
# 29           1  AMD Ryzen 5 1600 Box     696      CPUs
# 30           1  AMD Ryzen 5 1600 Box     696      CPUs
# 31           1  AMD Ryzen 5 1600 Box     696      CPUs
# 32           1  AMD Ryzen 5 1600 Box     696      CPUs
# 33           1  AMD Ryzen 5 1600 Box     696      CPUs
# 34           1  AMD Ryzen 5 1600 Box     696      CPUs
# 35           1  AMD Ryzen 5 1600 Box     696      CPUs
# 36           1  AMD Ryzen 5 1600 Box     696      CPUs
# 37           1  AMD Ryzen 5 1600 Box     696      CPUs
# 38           1  AMD Ryzen 5 1600 Box     696      CPUs
# 39           1  AMD Ryzen 5 1600 Box     696      CPUs
# 40           1  AMD Ryzen 5 1600 Box     696      CPUs

# %%
# Número de clusters.
print("Number of clusters: ", len(set(df.cluster_id)))
# Número de categorias.
print("Number of categs: ", len(set(df.cat_id)))
# Out:
# Number of clusters:  63995
# Number of categs:  12

# %%
df.cat_title.value_counts().plot(kind="bar", xlabel="Categs.", ylabel="Qtde", grid=True)
# Out:
# <AxesSubplot:xlabel='Categs.', ylabel='Qtde'>

# %%
df[(df.cat_title != "Men's Watches") & (df.cat_title != "Women's Watches")].cat_title.value_counts(normalize=True).plot(kind="bar", xlabel="Categs.", ylabel="Qtde", grid=True)
# Out:
# <AxesSubplot:xlabel='Categs.', ylabel='Qtde'>

# %% [markdown]
# ## Juntar as categorias com as câmeras em uma só.

# %%
df[df.cat_title.str.find('Analog') > -1]
# Out:
#           p_id                                            p_title  vendor_id  \
# 231910  386332       fujifilm instax mini 9 flamingorose 16550538       4511
# 231911  386333  fujifilm instax mini 9 62 x 46mm green lime in...       3021
# 231912  386334  fujifilm instax mini 9 flamingorose pliromi ke...       3003
# 231913  386335                     fujifilm instax mini 9 iceblue       2723
# 231914  386336                 fujifilm instax mini 9 cobalt blue       4835
# ...        ...                                                ...        ...
# 232300  386722                              lomography diana mini        522
# 232301  386723               lomography actionsampler transparent        522
# 232302  386724                                 lomography diana f        522
# 232303  386725                                 lomography oktomat        522
# 232304  386726          agfa le box vista ocean ipovrichia kamera       1445
#
#         cluster_id                   cluster_title  cat_id       cat_title
# 231910      105443          Fujifilm Instax Mini 9    2058  Analog Cameras
# 231911      105443          Fujifilm Instax Mini 9    2058  Analog Cameras
# 231912      105443          Fujifilm Instax Mini 9    2058  Analog Cameras
# 231913      105443          Fujifilm Instax Mini 9    2058  Analog Cameras
# 231914      105443          Fujifilm Instax Mini 9    2058  Analog Cameras
# ...            ...                             ...     ...             ...
# 232300      105545           Lomography Diana Mini    2058  Analog Cameras
# 232301      105546  Lomography ActionSampler Clear    2058  Analog Cameras
# 232302      105547             Lomography Diana F+    2058  Analog Cameras
# 232303      105548              Lomography Oktomat    2058  Analog Cameras
# 232304      105549           AgfaPhoto LeBox Vista    2058  Analog Cameras
#
# [395 rows x 7 columns]

# %%
cams = {
    "Compact Cameras": "Cameras",
    "DSLR Cameras": "Cameras",
    "Mirrorless Cameras": "Cameras",
    "Analog Cameras": "Cameras",
}
df.cat_title.replace(cams, inplace=True)
df.cat_title.value_counts().plot(kind="bar", xlabel="Categs.", ylabel="Qtde", grid=True)
# Out:
# <AxesSubplot:xlabel='Categs.', ylabel='Qtde'>
